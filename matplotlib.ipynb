# %% [markdown]
# <a href="https://colab.research.google.com/github/uedukondalu/ML-23ag1a66i8/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=np.array([2,3,4])
y=np.array([5,6,7])
plt.plot(x,y)
plt.show()
